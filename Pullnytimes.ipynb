# %%
# !pip install pynytimes

drive.mount ('/drive/')
# Out:
# ...
#      |████████████████████████████████| 62 kB 383 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from pynytimes import *
from google.colab import drive
import datetime
import os
import json

key = "RJVGdrtReKgdX9otDuBVB6Hjv4oBxapS"
nyt = NYTAPI (key, True)
 
totallen = 0
for i in range (2004,2023):
  l={}
  for j in range (1,13):
    
      try:
        print ('Now processing year {}, month {}'.format (i,j))
        data  = nyt.archive_metadata(datetime.datetime (i,j,1))
        l[j] =data        
        print ('{} articles processed'.format (len(data)))
        totallen+=len(data)
      except:
        break
  with open(os.path.join('/drive/MyDrive/timesdata',f'{i}.json'), 'w') as fout:
    print ('writing...')
    json.dump (l,fout,ensure_ascii=False);

print ('{} articles processed.'.format(totallen))
# Out:
# Now processing year 2004, month 1
# 8810 articles processed
# Now processing year 2004, month 2
# 8750 articles processed
# Now processing year 2004, month 3
# 8986 articles processed
# Now processing year 2004, month 4
# 8519 articles processed
# Now processing year 2004, month 5
# 8899 articles processed
# Now processing year 2004, month 6
# 8436 articles processed
# Now processing year 2004, month 7
# 8696 articles processed
# Now processing year 2004, month 8
# 8682 articles processed
# Now processing year 2004, month 9
# 9131 articles processed
# Now processing year 2004, month 10
# 10876 articles processed
# Now processing year 2004, month 11
# 8997 articles processed
# Now processing year 2004, month 12
# 9165 articles processed
# writing...
# Now processing year 2005, month 1
# 10567 articles processed
# Now processing year 2005, month 2
# 9311 articles processed
# Now processing year 2005, month 3
# 10262 articles processed
# Now processing year 2005, month 4
# ...

# %%
import os
os.chdir("/drive/MyDrive")
# !ls
# Out:
# Pullnytimes.ipynb  timesdata
